# %%
import pandas as pd
data = pd.read_csv('Churn_Modelling.csv')

# %%
del data['RowNumber']

# %%
numeric_data = data.copy()

for column in ['Surname', 'Geography', 'Gender']:
    numeric_data[column] = numeric_data[column].astype('category').cat.codes

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

# %%
from sklearn.linear_model import LogisticRegression

# %%
dataset = numeric_data.copy()
dataset.head()
# Out:
#    CustomerId  Surname  CreditScore  Geography  Gender  Age  Tenure  \
# 0    15634602     1115          619          0       0   42       2
# 1    15647311     1177          608          2       0   41       1
# 2    15619304     2040          502          0       0   42       8
# 3    15701354      289          699          0       0   39       1
# 4    15737888     1822          850          2       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
del dataset['CustomerId']
del dataset['Surname']

# %%
points = dataset['Exited']
values = dataset.drop(['Exited'], axis = 1)

# %%
train_values, test_values, train_points, test_points = train_test_split(values, points, test_size=0.2)

# %%
logreg = LogisticRegression()
logreg.fit(train_values, train_points)
# Out:
# C:\Users\micro\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logreg.predict(test_values)
y_pred_proba = logreg.predict_proba(test_values)[:, 1]

accuracy = accuracy_score(test_points, y_pred)
auc_roc = roc_auc_score(test_points, y_pred_proba)
report = classification_report(test_points, y_pred)

print('Accuracy:', accuracy)
print('AUC-ROC:', auc_roc)
print('Classification Report:\n', report)
# Out:
# Accuracy: 0.8045
# AUC-ROC: 0.6524705232856185
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      1605
#            1       0.54      0.08      0.13       395
#
#     accuracy                           0.80      2000
#    macro avg       0.67      0.53      0.51      2000
# weighted avg       0.76      0.80      0.74      2000

# %%
len(train_values)
# Out:
# 8000

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
    #sampling_strategy='auto',  # Стратегия выборки. 'auto' означает увеличение меньшего класса до размера большинственного.
    #random_state=None,         # Зерно для генератора случайных чисел.
    #k_neighbors=5,             # Количество ближайших соседей для создания синтетических примеров.
    #n_jobs=1                   # Количество ядер для параллельной работы. -1 означает использование всех доступных ядер.
#)

# %%
train_values_resampled, train_points_resampled = smote.fit_resample(train_values, train_points)

# %%
len(train_values_resampled)
# Out:
# 12704

# %%
logreg_smote = LogisticRegression()
logreg_smote.fit(train_values_resampled, train_points_resampled)
# Out:
# C:\Users\micro\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logreg.predict(test_values)
y_pred_proba = logreg.predict_proba(test_values)[:, 1]

accuracy = accuracy_score(test_points, y_pred)
auc_roc = roc_auc_score(test_points, y_pred_proba)
report = classification_report(test_points, y_pred)

print('Accuracy:', accuracy)
print('AUC-ROC:', auc_roc)
print('Classification Report:\n', report)
# Out:
# Accuracy: 0.8045
# AUC-ROC: 0.6524705232856185
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      1605
#            1       0.54      0.08      0.13       395
#
#     accuracy                           0.80      2000
#    macro avg       0.67      0.53      0.51      2000
# weighted avg       0.76      0.80      0.74      2000

# %%
from sklearn.feature_selection import RFE

# %%
columns = train_values.columns
os_values = pd.DataFrame(data=test_values,columns=columns )
os_points= pd.DataFrame(data=test_points,columns=['Exited'])

# %%
rfe = RFE(logreg)
rfe = rfe.fit(os_values, os_points.values.ravel())
print(rfe.support_)
print(rfe.ranking_)
# Out:
# C:\Users\micro\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\micro\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
significant_features = ['Geography', 'Gender', 'Age', 'HasCrCard', 'IsActiveMember']

# %%
revalues = values[significant_features]

# %%
train_values, test_values, train_points, test_points = train_test_split(revalues, points, test_size=0.2)

# %%
logreg_rfe = LogisticRegression()
logreg_rfe.fit(train_values, train_points)
# Out:
# C:\Users\micro\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logreg_rfe.predict(test_values)
y_pred_proba = logreg_rfe.predict_proba(test_values)[:, 1]

accuracy = accuracy_score(test_points, y_pred)
auc_roc = roc_auc_score(test_points, y_pred_proba)
report = classification_report(test_points, y_pred)

print('Accuracy:', accuracy)
print('AUC-ROC:', auc_roc)
print('Classification Report:\n', report)
# Out:
# Accuracy: 0.8045
# AUC-ROC: 0.6524705232856185
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      1605
#            1       0.54      0.08      0.13       395
#
#     accuracy                           0.80      2000
#    macro avg       0.67      0.53      0.51      2000
# weighted avg       0.76      0.80      0.74      2000

# %%
train_values_resampled, train_points_resampled = smote.fit_resample(train_values, train_points)

# %%
logreg_rfe_smote = LogisticRegression()
logreg_rfe_smote.fit(train_values_resampled, train_points_resampled)
# Out:
# C:\Users\micro\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logreg_rfe_smote.predict(test_values)
y_pred_proba = logreg_rfe_smote.predict_proba(test_values)[:, 1]

accuracy = accuracy_score(test_points, y_pred)
auc_roc = roc_auc_score(test_points, y_pred_proba)
report = classification_report(test_points, y_pred)

print('Accuracy:', accuracy)
print('AUC-ROC:', auc_roc)
print('Classification Report:\n', report)
# Out:
# Accuracy: 0.6625
# AUC-ROC: 0.6916850033518672
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.68      0.76      1605
#            1       0.32      0.61      0.42       395
#
#     accuracy                           0.66      2000
#    macro avg       0.60      0.64      0.59      2000
# weighted avg       0.77      0.66      0.69      2000

# %%
from joblib import dump

# %%
dump(logreg, 'logreg.joblib')
dump(logreg_smote, 'logreg_smote.joblib')
dump(logreg_rfe, 'logreg_rfe.joblib')
dump(logreg_smote, 'logreg_rfe_smote.joblib')
# Out:
# ['logreg_rfe_smote.joblib']
